# %%
# %pylab inline

# %%
import dataiku
from dataiku import pandasutils as pdu
import pandas as pd

# %%
# Read the dataset as a Pandas dataframe in memory
# Note: here, we only read the first 100K rows. Other sampling options are available
dataset_Twi_Data_place_name_empty_filled_prepared = dataiku.Dataset("Twi_Data_place_name_empty_filled_prepared")
df = dataset_Twi_Data_place_name_empty_filled_prepared.get_dataframe(limit=10000)

# %%
# Get some simple descriptive statistics
pdu.audit(df)
# Out:
#                 _a_variable    _b_data_type  _c_cardinality  _d_missings                                   _e_sample_values
# 0               screen_name          object             851            0                         [atheeralrsh2, aeyshamari]
# 1                 date_time  datetime64[ns]            9807            0  [2019-09-15T16:48:22.000000000, 2019-09-22T19:...
# 2                is_weekend            bool               2            0                                      [True, False]
# 3                      lang          object              33            0                                           [en, tl]
# 4                       app          object               6            0                             [swarmapp, foursquare]
# 5          tweet_text_clean          object            4976            0  [i'm at ask coffe in al kuwayt, al farwaniyah,...
# 6                  geopoint          object            3791            0  [POINT(47.909863 29.294962), POINT(47.9545 29....
# 7   place_name_clean_filled          object             149            0     [abdullah al mubarak - west jleeb, abu halifa]
# 8               governorate          object               6            0                               [Farwaniya, Hawalli]
# 9                 districts          object             139            5                           [Ardhiya - 6, Farwaniya]
# 10         place_name_tweet          object            2339          853                             [ask coffe, starbucks]

# %%
df.head()
# Out:
#     screen_name           date_time  is_weekend lang       app                                   tweet_text_clean                    geopoint           place_name_clean_filled governorate    districts place_name_tweet
# 0  atheeralrsh2 2019-09-15 16:48:22        True   en  swarmapp       i'm at ask coffe in al kuwayt, al farwaniyah  POINT(47.909863 29.294962)  abdullah al mubarak - west jleeb   Farwaniya  Ardhiya - 6        ask coffe
# 1  atheeralrsh2 2019-09-22 19:22:51        True   en  swarmapp       i'm at starbucks in al kuwayt, al farwaniyah    POINT(47.9545 29.278748)                        abu halifa   Farwaniya    Farwaniya        starbucks
# 2  atheeralrsh2 2019-09-28 14:34:48        True   en  swarmapp     i'm at drop coffee in al kuwayt, al farwaniyah   POINT(47.91403 29.304995)                      airport area   Farwaniya       Riggae      drop coffee
# 3  atheeralrsh2 2019-10-08 22:54:48       False   en  swarmapp  i'm at cinescape - @mall360 in kuwait city, mu...   POINT(47.99262 29.267715)                  abdulla al salem     Hawalli        Zahra         360 mall
# 4  atheeralrsh2 2019-10-26 19:24:16        True   en  swarmapp        i'm at @starbucks in kuwait city, al asimah   POINT(47.99838 29.357145)                  abdulla al salem     Capital   Mansouriya        starbucks
